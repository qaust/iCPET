# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

from sklearn.compose import (
	ColumnTransformer
)
from sklearn.decomposition import (
	PCA
)
from sklearn.ensemble import (
	RandomForestClassifier
)
from sklearn.linear_model import (
	LogisticRegression
)
from sklearn.metrics import (
	confusion_matrix,
	classification_report,
	f1_score,
)
from sklearn.model_selection import (
	train_test_split,
	RandomizedSearchCV,
	GridSearchCV,
	cross_val_score,
)
from sklearn.pipeline import (
	Pipeline
)
from sklearn.preprocessing import (
	LabelEncoder,
	OneHotEncoder,
	StandardScaler,
	RobustScaler,
	QuantileTransformer,
)

from pathlib import Path
import os
import pickle
from tqdm import tqdm

# %%
import regression.reg as reg

# %%
df = pd.read_pickle('../data/clinical.pickle')

# Set index to be PE number
df.index = df.pe_study_number

# Identify columns to drop
cols_to_drop = [
	'pe_study_number', # ID var
	'age', # More precise study_age calculated
	'dob_mask', # Not needed
	'study_date_mask', # Not needed
]

df = df.loc[:, df.columns.difference(cols_to_drop)]
df.head()
# Out:
#                 approached_ventilatory_ceiling        bmi borderline_ph   bsa  \
# pe_study_number
# PE1                                        0.0  35.500000             1  2.87
# PE11                                       NaN  33.070000             0  2.07
# PE12                                       0.0  32.720000             0  2.34
# PE14                                       0.0  30.455938             0  1.95
# PE15                                       0.0  21.430000             0  1.56
#
#                 deconditioning  eph  estimated_peak_vo2_ml_kg_min  \
# pe_study_number
# PE1                        1.0  0.0                          24.0
# PE11                       NaN  NaN                          20.9
# PE12                       1.0  0.0                          27.4
# PE14                       0.0  0.0                          23.7
# PE15                       0.0  0.0                          35.2
#
#                  estimated_peak_vo2_ml_min exercise_hfpef  \
# pe_study_number
# PE1                                 3604.0            0.0
# PE11                                1993.0            NaN
# PE12                                3045.0            0.0
# PE14                                2027.0            0.0
# PE15                                1930.0            0.0
#
#                 exercise_ph_resting_hfpef  ... resting_ph_exercise_hfpef  \
# pe_study_number                            ...
# PE1                                   0.0  ...                       0.0
# PE11                                  NaN  ...                       NaN
# PE12                                  0.0  ...                       0.0
# PE14                                  0.0  ...                       0.0
# PE15                                  0.0  ...                       0.0
#
#                  study_age surpassed_ventilatory_ceiling  \
# pe_study_number
# PE1              49.886379                           0.0
# PE11             37.026694                           NaN
# PE12             45.412731                           0.0
# PE14             31.616701                           0.0
# PE15             18.699521                           0.0
#
#                  systemic_htn_response ve_vco2_at_at ve_vco2_slope  \
# pe_study_number
# PE1                                0.0          31.0           NaN
# PE11                               NaN          41.0        46.877
# PE12                               0.0          31.0        29.557
# PE14                               1.0          30.0        32.776
# PE15                               0.0          31.0        28.446
#
#                  vo2_hr_peak_percent_  vo2_ml_kg_min_at_at  \
# pe_study_number
# PE1                              45.0                  9.6
# PE11                             83.0                  8.1
# PE12                             75.0                 10.7
# PE14                             92.0                 10.2
# PE15                             80.0                 17.1
#
#                  vo2_work_slope_output  weight_kg
# pe_study_number
# PE1                                NaN     150.00
# PE11                             7.805      95.60
# PE12                             8.038     111.50
# PE14                             7.718      85.55
# PE15                               NaN      55.00
#
# [5 rows x 48 columns]

# %%
df.resolved_pe.value_counts()
# Out:
# Unresolved    28
# Resolved      16
# Name: resolved_pe, dtype: int64

# %%
ttests_df = reg.numeric_ttests(df, 'resolved_pe')
ttests_df.to_csv('../output/summary/iCPET_numeric_ttests_resolved.csv')
ttests_df.loc[ttests_df.p_value <= 0.05, :]
# Out:
#                       mean_Resolved  mean_Unresolved  count_Resolved  \
# peak_cavo2                13.827425        12.125982            15.0
# percent_co_achieved       73.066667        92.917536            15.0
# percent_peak_vo2          68.267023        77.701205            16.0
# study_age                 58.486653        48.892148            16.0
# vo2_hr_peak_percent_      79.875000        91.928571            16.0
#
#                       count_Unresolved  std_Resolved  std_Unresolved  \
# peak_cavo2                        28.0      2.208464        2.344787
# percent_co_achieved               28.0     20.512581       18.184435
# percent_peak_vo2                  28.0     12.521529       17.493514
# study_age                         28.0     13.828059       15.542087
# vo2_hr_peak_percent_              28.0     12.996794       18.348334
#
#                         t_stat   p_value significance
# peak_cavo2            2.356054  0.025132            *
# percent_co_achieved  -3.144172  0.004149           **
# percent_peak_vo2     -2.072137  0.044793            *
# study_age             2.115053  0.041726            *
# vo2_hr_peak_percent_ -2.536559  0.015213            *

# %%
ttests_df = reg.numeric_ttests(df, ['normal', 'resolved_pe'])
ttests_df.to_csv('../output/summary/iCPET_numeric_ttests_resolved_normal.csv')
ttests_df.loc[ttests_df.p_value <= 0.05, :]
# Out:
#                        mean_Resolved_0  mean_Resolved_1  mean_Unresolved_0  \
# peak_cavo2                   14.027987        13.025180          11.019484
# peak_fick_co                 11.229420        12.352693          12.150020
# peak_vo2_ml_min            1528.230769      1540.666667        1306.357143
# percent_co_achieved          65.319167       104.056667          85.779286
# percent_peak_vo2             63.710172        88.013377          63.334379
# percent_vo2_at_at            43.453004        72.449789          46.442196
# vo2_hr_peak_percent_         78.307692        86.666667          80.071429
# vo2_work_slope_output         7.815091         7.993333           6.900818
#
#                        mean_Unresolved_1  count_Resolved_0  count_Resolved_1  \
# peak_cavo2                     13.232480              12.0               3.0
# peak_fick_co                   14.720721              12.0               3.0
# peak_vo2_ml_min              1911.428571              13.0               3.0
# percent_co_achieved           100.055786              12.0               3.0
# percent_peak_vo2               92.068032              13.0               3.0
# percent_vo2_at_at              59.862613              13.0               3.0
# vo2_hr_peak_percent_          103.785714              13.0               3.0
# vo2_work_slope_output           8.803692              11.0               3.0
#
#                        count_Unresolved_0  count_Unresolved_1  std_Resolved_0  \
# peak_cavo2                           14.0                14.0        2.099872
# peak_fick_co                         14.0                14.0        3.516874
# peak_vo2_ml_min                      14.0                14.0      414.046325
# percent_co_achieved                  14.0                14.0       10.008129
# percent_peak_vo2                     14.0                14.0        8.678020
# percent_vo2_at_at                    14.0                14.0        8.941279
# vo2_hr_peak_percent_                 14.0                14.0       13.275194
# vo2_work_slope_output                11.0                13.0        1.296254
#
#                        std_Resolved_1  std_Unresolved_0  std_Unresolved_1  \
# peak_cavo2                   2.946591          1.612898          2.486063
# peak_fick_co                 2.643598          3.220509          2.534176
# peak_vo2_ml_min            625.743025        386.678083        542.554317
# percent_co_achieved         24.367081         16.508101         17.450444
# percent_peak_vo2             2.053624         10.220461          9.303889
# percent_vo2_at_at            8.446047          8.925455          9.297344
# vo2_hr_peak_percent_        11.150486         13.228549         14.879922
# vo2_work_slope_output        1.281058          1.343854          0.946651
#
#                           t_stat       p_value significance
# peak_cavo2              4.691443  6.836797e-03           **
# peak_fick_co            3.092703  3.796509e-02            *
# peak_vo2_ml_min         4.065624  1.301000e-02            *
# percent_co_achieved    11.786838  1.230585e-05          ***
# percent_peak_vo2       31.907072  1.065774e-10          ***
# percent_vo2_at_at      14.289342  1.781012e-06          ***
# vo2_hr_peak_percent_    9.908908  5.156839e-05          ***
# vo2_work_slope_output   5.030363  5.421008e-03           **

# %%
# sns.pairplot(
# 	data=df,
# 	vars=df.select_dtypes(['float']).columns,
# 	hue='resolved_pe',
# 	diag_kind='kde'
# )
# plt.savefig('../figures/iCPET_numeric_pairplot.png')
# plt.show()

# %%
# Identify columns to drop
cols_to_drop = [
	've_vco2_slope', # Missing values
	'vo2_work_slope_output', # Missing values
]

# Subset data and remove remaining NaN observations
# Should only lose 2 observations
df_clean = df.loc[:, df.columns.difference(cols_to_drop)]
df_clean = df_clean.dropna()

df_clean.shape
# Out:
# (39, 46)

# %%
target_columns = ['resolved_pe']
numeric_columns = df_clean.select_dtypes(['int', 'float']).columns
categorical_columns = df_clean.select_dtypes(['category']).columns.difference(target_columns)

# %%
target_pipeline = Pipeline([
	('LabelEncoder', LabelEncoder())
])

numeric_pipeline = Pipeline([
	('Scaler', StandardScaler)
])

categorical_pipeline = Pipeline([
	('OneHotEncoder', OneHotEncoder())
])

preprocessor = ColumnTransformer([
	('target', target_pipeline, target_columns),
	('numeric', numeric_pipeline, numeric_columns),
	('categorical', categorical_pipeline, categorical_columns),
])

# %%
# df_preprocessed = preprocessor.fit_transform(df_clean)
# df_preprocessed.head()

# %% [markdown]
# ## Analysis
# ### Graphical Models
#
# Plan to use https://pgmpy.org/index.html (great tutorials)
# https://pgmpy.org/detailed_notebooks/10.%20Learning%20Bayesian%20Networks%20from%20Data.html
