# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style as style
from matplotlib.colors import ListedColormap
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.linear_model import LogisticRegression

# %%
style.use('ggplot')
# sns.set_theme()

# %%
# df = pd.read_excel("data/PE_merged (12-11-2022).xlsx", sheet_name="PE (merged)")

# %% [markdown]
# # Cleaning / Preprocessing

# %% [markdown]
# ## PE Risbano Data

# %%
pe = pd.read_excel("data/PE_merged (12-11-2022).xlsx", sheet_name="PE")

# %%
pe['date'] = pd.to_datetime(pe['study_date'], format="%Y%m%d")

# %%
pe.rename(columns={'patient_name': 'pe_number'}, inplace=True)

# %%
tuples = list(zip(pe['pe_number'], pe['date']))
new_idx = pd.MultiIndex.from_tuples(tuples, names=['PE Number', 'Study Date'])
pe.index = new_idx

# %%
pe['clot_burden_additive'] = pe.iloc[:, list(pe.columns).index("Apical_R-S1"):list(pe.columns).index("Posterior_Basal_L-S10")+1].sum(axis=1)
pe['clot_burden_additive'].head()
# Out:
# PE Number  Study Date
# PE1        2014-01-07    205.535670
# PE12       2021-12-03     75.827757
#            2020-12-18    190.970071
# PE14       2018-12-19    126.536620
# PE15       2020-09-18     81.828530
# Name: clot_burden_additive, dtype: float64

# %% [markdown]
# ## iCPET Data

# %%
cl = pd.read_excel("data/PE_merged (12-11-2022).xlsx", sheet_name="Clinical Data")

# %%
cl['date'] = pd.to_datetime(cl['1st iCPET'])
cl['Peak  PVR (WU)'] = pd.to_numeric(cl['Peak  PVR (WU)'])

# %%
cl.rename(columns={'PE Number clean': 'pe_number'}, 
          inplace=True)

# %%
cl['Resolved'] = cl['Resolved PE'].astype('category')
cl['Resolved'].cat.categories
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
cl['Resolved'] = cl['Resolved'].cat.rename_categories({0: 'Chronic', 1: 'Resolved'})
cl['Resolved'].cat.categories
# Out:
# Index(['Chronic', 'Resolved'], dtype='object')

# %% [markdown]
# ## Merge Data

# %%
pe.sort_values(by=['date'], inplace=True)
cl.sort_values(by=['date'], inplace=True)

# Need the clinical data to be the left df
# Merging on pe number and closest date
df = pd.merge_asof(cl, pe, on='date', by='pe_number', direction='nearest')
df.sort_values(by=['pe_number'], inplace=True)

# %%
df.to_csv('output/test.csv')

# %% [markdown]
# # Correlation Plots

# %% [markdown]
# # Research questions

# %% [markdown]
# ## clot characteristics

# %%
fields = [
    'pe_number',
    'clot_burden_additive',
    'Resolved',
    'VE/VCO2 at AT',
    'Peak  Measured mPAP (mmHg)',
    'Peak  PVR (WU)',
    'Peak  C(A-V)O2',
    'Peak  P(A-a)O2',
    'Peak  Fick CO',
    'Peak  VD/VT',
]

df_sub_long = df[fields].melt(id_vars=['pe_number', 'clot_burden_additive', 'Resolved'])
df_sub_long.head()
# Out:
#   pe_number  clot_burden_additive  Resolved       variable  value
# 0       PE1            205.535670  Resolved  VE/VCO2 at AT   31.0
# 1      PE11                   NaN  Resolved  VE/VCO2 at AT   41.0
# 2      PE12             75.827757   Chronic  VE/VCO2 at AT   31.0
# 3      PE14            126.536620   Chronic  VE/VCO2 at AT   30.0
# 4      PE15            121.891910   Chronic  VE/VCO2 at AT   31.0

# %%
g = sns.lmplot(
    data=df_sub_long,
    x='clot_burden_additive',
    y='value',
    hue='Resolved',
    col='variable',
    col_wrap=3,
    height=2.5,
    aspect=1.5,
    facet_kws={'sharey': False},
)

plt.savefig('output/plots/lm_clot_burden_v_relationships')

# %% [markdown]
# ## body composition tissues effect on PE resolving and the PE clot burden?

# %% [markdown]
# ## impact of body composition on the PE changes over time

# %% [markdown]
# ## association between PE clot volumes and the artery/vein volumes

# %% [markdown]
# # Old

# %% [markdown]
# ### Convert study date to datetime

# %%
df['study_date_fmt'] = pd.to_datetime(df['study_date_fmt'], format="%Y-%m-%d")
df['study_date_fmt'].head()
# Out:
# 0   2014-01-07
# 1   2021-12-03
# 2   2020-12-18
# 3   2018-12-19
# 4   2020-09-18
# Name: study_date_fmt, dtype: datetime64[ns]

# %% [markdown]
# ### Generate new index with PE number and study date

# %%
tuples = list(zip(df['patient_name'], df['study_date_fmt']))
new_idx = pd.MultiIndex.from_tuples(tuples, names=['PE Number', 'Study Date'])
df.index = new_idx
df.head()
# Out:
#                      patient_name patient_id  study_date study_date_fmt  \
# PE Number Study Date
# PE1       2014-01-07          PE1   HB046619    20140107     2014-01-07
# PE12      2021-12-03         PE12   HB046622    20211203     2021-12-03
#           2020-12-18         PE12   HB046622    20201218     2020-12-18
# PE14      2018-12-19         PE14   HB046616    20181219     2018-12-19
# PE15      2020-09-18         PE15   HB046618    20200918     2020-09-18
#
#                       max_date age_str gender_str   DOB_str  series_id  \
# PE Number Study Date
# PE1       2014-01-07         1    045Y          M  19680101          3
# PE12      2021-12-03         1    045Y          M  19760101          3
#           2020-12-18         0    044Y          M  19760101          5
# PE14      2018-12-19         1    031Y          F  19870101          3
# PE15      2020-09-18         1    019Y          F  20000101          2
#
#                       slice_number  ...  Peak  PVR (WU)  Peak  Arterial Hb  \
# PE Number Study Date                ...
# PE1       2014-01-07           174  ...        1.025641               15.4
# PE12      2021-12-03            95  ...        0.916936               15.6
#           2020-12-18           264  ...             NaN                NaN
# PE14      2018-12-19           167  ...        1.314348               12.1
# PE15      2020-09-18           383  ...             NaN                NaN
#
#                       Peak  CaO2  Peak  CvO2  Peak  C(A-V)O2  Peak  P(A-a)O2  \
# PE Number Study Date
# PE1       2014-01-07    20.46894     6.82500        13.64394        2.905439
# PE12      2021-12-03    20.68356     8.21862        12.46494       19.274715
#           2020-12-18         NaN         NaN             NaN             NaN
# PE14      2018-12-19    16.34052     7.41872         8.92180        3.302519
# PE15      2020-09-18         NaN         NaN             NaN             NaN
#
#                       Peak  Fick CO  Peak  VD/VT  Peak  C(A-V)O2 a art Hb  \
# PE Number Study Date
# PE1       2014-01-07      15.604727     0.130000                 0.885970
# PE12      2021-12-03      16.523663     0.205714                 0.799035
#           2020-12-18            NaN          NaN                      NaN
# PE14      2018-12-19      18.254263     0.210000                 0.737339
# PE15      2020-09-18            NaN          NaN                      NaN
#
#                       clot_burden_additive
# PE Number Study Date
# PE1       2014-01-07            205.535670
# PE12      2021-12-03             75.827757
#           2020-12-18            190.970071
# PE14      2018-12-19            126.536620
# PE15      2020-09-18             81.828530
#
# [5 rows x 119 columns]

# %% [markdown]
# ### Generate clot burden variable

# %%
df['clot_burden_additive'] = df.iloc[:, list(df.columns).index("Apical_R-S1"):list(df.columns).index("Posterior_Basal_L-S10")+1].sum(axis=1)
df['clot_burden_additive'].head()
# Out:
# 0    205.535670
# 1     75.827757
# 2    190.970071
# 3    126.536620
# 4     81.828530
# Name: clot_burden_additive, dtype: float64

# %%
df.loc['PE15', 'clot_burden_additive'].plot(marker=".")
# Out:
# <AxesSubplot:xlabel='Study Date'>

# %%
g = sns.relplot(
    data=df, x="study_date_fmt", y="clot_burden_additive",
    row="patient_name", 
    kind="line", marker=".",
    height=2, aspect=3.5,
    facet_kws={'sharey': True, 'sharex': False}
)
